# %%
cd /content/drive/MyDrive/Tensorflow Developer/Car Number Plate
# Out:
# /content/drive/MyDrive/Tensorflow Developer/Car Number Plate

# %%
# !pip install tensorflow-gpu==2.7.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 489.6 MB 23 kB/s
# ...
#      |████████████████████████████████| 463 kB 75.5 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 61.5 MB/s
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
import os
import pathlib

import matplotlib
import matplotlib.pyplot as plt

import io
import scipy.misc
import numpy as np
from six import BytesIO
from PIL import Image, ImageDraw, ImageFont
from six.moves.urllib.request import urlopen

import tensorflow as tf
import tensorflow_hub as hub

tf.get_logger().setLevel('ERROR')

# %%
# !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 3406, done.
# remote: Counting objects: 100% (3406/3406), done.
# remote: Compressing objects: 100% (2833/2833), done.
# remote: Total 3406 (delta 895), reused 1434 (delta 516), pack-reused 0
# Receiving objects: 100% (3406/3406), 34.96 MiB | 15.77 MiB/s, done.
# Resolving deltas: 100% (895/895), done.
# Checking out files: 100% (3087/3087), done.

# %%
cd models/research
# Out:
# /content/drive/MyDrive/Tensorflow Developer/Car Number Plate/models/research

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
#Cloning Coco API
# !git clone https://github.com/cocodataset/cocoapi.git
# Out:
# Cloning into 'cocoapi'...
# remote: Enumerating objects: 975, done.
# remote: Total 975 (delta 0), reused 0 (delta 0), pack-reused 975
# Receiving objects: 100% (975/975), 11.72 MiB | 14.11 MiB/s, done.
# Resolving deltas: 100% (576/576), done.

# %%
# Out:
#   File "<ipython-input-8-7c34ab3add99>", line 2
#     cd cocoapi/PythonAPI
#              ^
# SyntaxError: invalid syntax

# %%
cd
# Out:
# /root

# %%
pwd
# Out:
# '/root'

# %%
cd /content/drive/MyDrive/Tensorflow Developer/Car Number Plate/models/research
# Out:
# /content/drive/MyDrive/Tensorflow Developer/Car Number Plate/models/research

# %%
pwd
# Out:
# '/content/drive/MyDrive/Tensorflow Developer/Car Number Plate/models/research'

# %%
cd cocoapi/PythonAPI
# Out:
# /content/drive/MyDrive/Tensorflow Developer/Car Number Plate/models/research/cocoapi/PythonAPI

# %%
# !make
# Out:
# python setup.py build_ext --inplace
# running build_ext
# cythoning pycocotools/_mask.pyx to pycocotools/_mask.c
# /usr/local/lib/python3.7/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/drive/MyDrive/Tensorflow Developer/Car Number Plate/models/research/cocoapi/PythonAPI/pycocotools/_mask.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'pycocotools._mask' extension
# creating build
# creating build/common
# creating build/temp.linux-x86_64-3.7
# creating build/temp.linux-x86_64-3.7/pycocotools
# ...

# %%
cp -r pycocotools /content/drive/MyDrive/Tensorflow Developer/Car Number Plate/models/research
# Out:
# cp: target 'Plate/models/research' is not a directory

# %%
pwd
# Out:
# '/content/drive/MyDrive/Tensorflow Developer/Car Number Plate/models/research/cocoapi/PythonAPI'

# %%
cd ..
# Out:
# /content/drive/MyDrive/Tensorflow Developer/Car Number Plate/models/research/cocoapi

# %%
cd ..
# Out:
# /content/drive/MyDrive/Tensorflow Developer/Car Number Plate/models/research

# %%
cd ..
# Out:
# /content/drive/MyDrive/Tensorflow Developer/Car Number Plate/models

# %%
cd ..
# Out:
# /content/drive/MyDrive/Tensorflow Developer/Car Number Plate

# %%
# %%bash
# cd models/research/
# protoc object_detection/protos/*.proto --python_out=.
# cp object_detection/packages/tf2/setup.py .
# python -m pip install --use-feature=2020-resolver .
# #python -m pip install -q .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/drive/MyDrive/Tensorflow Developer/Car Number Plate/models/research
# ...
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1694837 sha256=76667ad577ca8cb24f4a7e20a84fe6c97609175765a715e0b40bcea47fd9edd1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2s3vx3ro/wheels/05/39/01/ae71850a0c54cdda20f2af06a6a32f73f4e00f719297aec941
# ...
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22257 sha256=6a6fd8eb5cc0a7886ae46d79e82ccd1d189ff0cf7e6bba38cf0876e8b5b064a1
#   Stored in directory: /root/.cache/pip/wheels/d2/f1/1f/041add21dc9c4220157f1bd2bd6afe1f1a49524c3396b94401
# ...
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78544 sha256=b45ec7d975d82b63323f459dd6429b6fa3a80140f9967e6a648914c443a43806
# ...

# %%
cd models/research
# Out:
# /content/drive/MyDrive/Tensorflow Developer/Car Number Plate/models/research

# %%
# !python object_detection/builders/model_builder_tf2_test.py
# Out:
# Running tests under Python 3.7.13: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2022-07-07 06:23:15.970956: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# W0707 06:23:16.183032 140399484360576 model_builder.py:1102] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.37s
# I0707 06:23:16.519157 140399484360576 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.37s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.48s
# ...

# %%
pwd
# Out:
# '/content/drive/MyDrive/Tensorflow Developer/Car Number Plate/models/research'

# %%
cd ..
# Out:
# /content/drive/MyDrive/Tensorflow Developer/Car Number Plate/models

# %%
cd ..
# Out:
# /content/drive/MyDrive/Tensorflow Developer/Car Number Plate

# %%
pwd
# Out:
# '/content/drive/MyDrive/Tensorflow Developer/Car Number Plate'

# %%
pwd
# Out:
# '/content/drive/MyDrive/Tensorflow Developer/Car Number Plate'

# %%
ls
# Out:
# generate_tfrecord.py  models/  training_demo/  Untitled0.ipynb

# %%
# Create train data:
# !python generate_tfrecord.py -x training_demo/images/train -l training_demo/annotations/label_map.pbtxt -o training_demo/annotations/train.record

# Create test data:
# !python generate_tfrecord.py -x training_demo/images/test -l training_demo/annotations/label_map.pbtxt -o training_demo/annotations/test.record
# Out:
# Successfully created the TFRecord file: training_demo/annotations/train.record
# Successfully created the TFRecord file: training_demo/annotations/test.record

# %%
cd ..
# Out:
# /content/drive/MyDrive/Tensorflow Developer

# %%
cd Car Number Plate
# Out:
# /content/drive/MyDrive/Tensorflow Developer/Car Number Plate

# %%
cd training_demo/pre-trained-models
# Out:
# /content/drive/MyDrive/Tensorflow Developer/Car Number Plate/training_demo/pre-trained-models

# %%
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/efficientdet_d2_coco17_tpu-32.tar.gz
# Out:
# --2022-07-07 06:47:24--  http://download.tensorflow.org/models/object_detection/tf2/20200711/efficientdet_d2_coco17_tpu-32.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 209.85.147.128, 2607:f8b0:4001:c54::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|209.85.147.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62929273 (60M) [application/x-tar]
# Saving to: ‘efficientdet_d2_coco17_tpu-32.tar.gz’
#
# efficientdet_d2_coc 100%[===================>]  60.01M  97.4MB/s    in 0.6s
#
# 2022-07-07 06:47:25 (97.4 MB/s) - ‘efficientdet_d2_coco17_tpu-32.tar.gz’ saved [62929273/62929273]

# %%
# !tar xvf efficientdet_d2_coco17_tpu-32.tar.gz
# Out:
# efficientdet_d2_coco17_tpu-32/
# efficientdet_d2_coco17_tpu-32/checkpoint/
# efficientdet_d2_coco17_tpu-32/checkpoint/ckpt-0.data-00000-of-00001
# efficientdet_d2_coco17_tpu-32/checkpoint/checkpoint
# efficientdet_d2_coco17_tpu-32/checkpoint/ckpt-0.index
# efficientdet_d2_coco17_tpu-32/pipeline.config
# efficientdet_d2_coco17_tpu-32/saved_model/
# efficientdet_d2_coco17_tpu-32/saved_model/saved_model.pb
# efficientdet_d2_coco17_tpu-32/saved_model/assets/
# efficientdet_d2_coco17_tpu-32/saved_model/variables/
# efficientdet_d2_coco17_tpu-32/saved_model/variables/variables.data-00000-of-00001
# efficientdet_d2_coco17_tpu-32/saved_model/variables/variables.index

# %%
pwd
# Out:
# '/content/drive/MyDrive/Tensorflow Developer/Car Number Plate/training_demo/pre-trained-models'

# %%
cd ..
# Out:
# /content/drive/MyDrive/Tensorflow Developer/Car Number Plate/training_demo

# %%
cd ..
# Out:
# /content/drive/MyDrive/Tensorflow Developer/Car Number Plate

# %%
# !pip uninstall opencv-python-headless==4.5.5.62
# Out:
# Found existing installation: opencv-python-headless 4.6.0.66
# Uninstalling opencv-python-headless-4.6.0.66:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/cv2/*
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless-4.6.0.66.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libavcodec-5896f664.so.58.134.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libavformat-8ef5c7db.so.58.76.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libavutil-9c768859.so.56.70.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libbz2-a273e504.so.1.0.6
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libcrypto-d21001fc.so.1.1
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libgfortran-91cc3cb1.so.3.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libopenblas-r0-f650aae0.3.3.so
# ...

# %%
# !pip install opencv-python-headless==4.1.2.30
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 21.8 MB 1.5 MB/s
# ...

# %%
# !python model_main_tf2.py --model_dir=training_demo/models/EfficientDet_D2 --pipeline_config_path=training_demo/models/EfficientDet_D2/pipeline.config
# Out:
# 2022-07-07 08:42:38.000675: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0707 08:42:38.004552 140198839347072 mirrored_strategy.py:376] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0707 08:42:38.010551 140198839347072 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0707 08:42:38.010743 140198839347072 config_util.py:552] Maybe overwriting use_bfloat16: False
# I0707 08:42:38.023315 140198839347072 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b2
# ...

# %%
pwd
# Out:
# '/content/drive/MyDrive/Tensorflow Developer/Car Number Plate'

# %%
# !python exporter_main_v2.py --input_type image_tensor --pipeline_config_path training_demo/models/EfficientDet_D2/pipeline.config --trained_checkpoint_dir training_demo/models/EfficientDet_D2 --output_directory training_demo/exported-models/my_model
# Out:
# 2022-07-07 09:27:46.509983: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0707 09:27:46.518228 139672126949248 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b2
# I0707 09:27:46.518488 139672126949248 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 112
# I0707 09:27:46.518573 139672126949248 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 5
# I0707 09:27:46.522102 139672126949248 efficientnet_model.py:147] round_filter input=32 output=32
# I0707 09:27:46.546749 139672126949248 efficientnet_model.py:147] round_filter input=32 output=32
# I0707 09:27:46.546856 139672126949248 efficientnet_model.py:147] round_filter input=16 output=16
# ...

# %%
pwd
# Out:
# '/content/drive/MyDrive/Tensorflow Developer/Car Number Plate'
